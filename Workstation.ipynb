# %%
from stats_all_files import * #get_nb_series, get_nb_all_files, get_nb_all_episodes, get_nb_episodes_per_serie, get_stats_languages, get_movie_infos
#import stats_all_files

# %%
current_directory = pathlib.Path('/vol/work3/maurice/dvd_extracted/')
set_current_directory(current_directory)

print('Number of series', get_nb_series())
print('Number of total files', get_nb_all_files())
print('Number of episodes', get_nb_all_episodes())
print('Number of episodes per serie', get_nb_episodes_per_serie())
#print('Languages statistics', get_stats_languages())
videos_infos = get_movie_infos()
print('Movie informations', videos_infos)
# Out:
# Number of series 23
# Number of total files 22816
# Number of episodes 1831
# Number of episodes per serie {'GameOfThrones': 60, '24HeuresChronoRedemption': 1, 'BattlestarGalactica': 72, 'BreakingBad': 62, 'Friends': 237, 'Homeland': 72, 'LeSeigneurDesAnneaux': 3, 'BattlestarGalacticaThePlan': 1, 'SixFeetUnder': 63, 'StarWars': 7, 'HarryPotter': 8, 'TheOffice': 200, 'TheWalkingDead': 99, 'Urgences': 331, '24HeuresChrono': 204, 'BattlestarGalacticaBloodAndChrome': 1, 'BattlestarGalacticaLaBatailleDeLEspaceLeFilm': 1, 'BattlestarGalacticaRazor': 1, 'BattlestarGalacticaCaprica': 18, 'BuffyContreLesVampires': 122, 'Lost': 61, 'TheBigBangTheory': 0}
# 0/23 /vol/work3/maurice/dvd_extracted/GameOfThrones
# 1/23 /vol/work3/maurice/dvd_extracted/24HeuresChronoRedemption
# 2/23 /vol/work3/maurice/dvd_extracted/BattlestarGalactica
# 3/23 /vol/work3/maurice/dvd_extracted/BreakingBad
# 4/23 /vol/work3/maurice/dvd_extracted/Friends
# 5/23 /vol/work3/maurice/dvd_extracted/Homeland
# ...

# %%
videos_infos['name'] = videos_infos['name'].str.strip()
videos_infos['season'] = videos_infos['season'].str.strip()
videos_infos['episode'] = videos_infos['episode'].str.strip()
videos_infos = videos_infos.reset_index(drop=True)
#videos_infos = videos_infos.drop(['index'], axis = 1)
print(videos_infos)
# Out:
#                   name season episode  duration  frame_rate  width  height
# 0        GameOfThrones     03      03   3039.30        25.0  720.0   576.0
# 1        GameOfThrones     03      04   3071.94        25.0  720.0   576.0
# 2        GameOfThrones     02      09   3134.10        25.0  720.0   576.0
# 3        GameOfThrones     02      10   3650.94        25.0  720.0   576.0
# 4        GameOfThrones     02      01   3031.94        25.0  720.0   576.0
# 5        GameOfThrones     02      02   3078.34        25.0  720.0   576.0
# 6        GameOfThrones     01      07   3325.10        25.0  720.0   576.0
# 7        GameOfThrones     01      08   3345.38        25.0  720.0   576.0
# 8        GameOfThrones     03      05   3304.42        25.0  720.0   576.0
# 9        GameOfThrones     03      06   3070.98        25.0  720.0   576.0
# 10       GameOfThrones     04      01   3350.10        25.0  720.0   576.0
# ...

# %%
#with pd.option_context('display.max_rows', None, 'display.max_columns', None):
#    print(videos_infos.sort_values('duration'))
def print_full(x):
    pd.set_option('display.max_rows', len(x))
    print(x)#.to_string())#index=False))
    pd.reset_option('display.max_rows')
#print_full(videos_infos)

# %%
for v in videos_infos.groupby('name')['duration'].mean().values:
    print(v)
# Out:
# 2236.3612254901973
# 5006.03
# 2622.0426388888886
# 5382.26
# 2696.8566666666666
# 7457.66
# 5968.98
# 6405.86
# 2744.0793548387114
# 2521.815327868852
# 1307.3764556962021
# 3173.7565517241374
# 8489.42
# 2973.7716666666665
# 10721.263333333334
# 2497.8365573770498
# 3241.301587301587
# 7758.655714285715
# 1194.7244444444439
# 1300.53805
# 2714.947878787879
# 2562.2456797583077

# %%
print(videos_infos.groupby('name')['duration'].mean())
# Out:
# name
# 24HeuresChrono                                   2236.361225
# 24HeuresChronoRedemption                         5006.030000
# BattlestarGalactica                              2622.042639
# BattlestarGalacticaBloodAndChrome                5382.260000
# BattlestarGalacticaCaprica                       2696.856667
# BattlestarGalacticaLaBatailleDeLEspaceLeFilm     7457.660000
# BattlestarGalacticaRazor                         5968.980000
# BattlestarGalacticaThePlan                       6405.860000
# BreakingBad                                      2744.079355
# BuffyContreLesVampires                           2521.815328
# Friends                                          1307.376456
# GameOfThrones                                    3173.756552
# HarryPotter                                      8489.420000
# Homeland                                         2973.771667
# LeSeigneurDesAnneaux                            10721.263333
# ...

# %%
videos_infos.groupby('name')['duration'].sum()
#for v in videos_infos.groupby('name')['duration'].sum().index:#values:
#    print(v)
# Out:
# name
# 24HeuresChrono                                  456217.69
# 24HeuresChronoRedemption                          5006.03
# BattlestarGalactica                             188787.07
# BattlestarGalacticaBloodAndChrome                 5382.26
# BattlestarGalacticaCaprica                       48543.42
# BattlestarGalacticaLaBatailleDeLEspaceLeFilm      7457.66
# BattlestarGalacticaRazor                          5968.98
# BattlestarGalacticaThePlan                        6405.86
# BreakingBad                                     170132.92
# BuffyContreLesVampires                          307661.47
# Friends                                         309848.22
# GameOfThrones                                   184077.88
# HarryPotter                                      67915.36
# Homeland                                        214111.56
# LeSeigneurDesAnneaux                             32163.79
# Lost                                            152368.03
# ...

# %%
videos_infos.sort_values('duration').head(35)
# Out:
#                         name season episode  duration  frame_rate  width  \
# 214                  Friends     01      07     40.79        25.0  702.0
# 1448          24HeuresChrono     02      04    119.03        25.0  704.0
# 1580          24HeuresChrono     04      16    136.02        25.0  718.0
# 1473          24HeuresChrono     03      20    155.05        25.0  720.0
# 1483          24HeuresChrono     03      12    159.17        25.0  720.0
# 1472          24HeuresChrono     03      19    179.42        25.0  716.0
# 360                  Friends     05      23    194.03        25.0  698.0
# 1455          24HeuresChrono     02      11    214.70        25.0  702.0
# 1460          24HeuresChrono     02      16    227.91        25.0  720.0
# 1596          24HeuresChrono     05      08    247.51        25.0  718.0
# 1176                Urgences     05      19    300.00        25.0  370.0
# 1588          24HeuresChrono     04      24    346.10        25.0  720.0
# ...

# %%
videos_infos.sort_values('width').head(535)
# Out:
#                                               name season episode  duration  \
# 1176                                      Urgences     05      19    300.00
# 1572                                24HeuresChrono     04      08    439.02
# 1570                                24HeuresChrono     04      06   2534.50
# 1767                        BuffyContreLesVampires     07      21   2459.02
# 52                                   GameOfThrones     06      03   3002.14
# 51                                   GameOfThrones     06      02   3088.62
# 1542                                24HeuresChrono     08      05   2538.22
# 1740                        BuffyContreLesVampires     05      17   2562.03
# 1624                                24HeuresChrono     09      12   2529.46
# 38                                   GameOfThrones     02      09   3134.10
# 1771                                          Lost     02      04   2488.12
# ...

# %%
videos_infos.sort_values('height').head(870)
# Out:
#                                               name season episode  duration  \
# 1626  BattlestarGalacticaLaBatailleDeLEspaceLeFilm     01      01   7457.66
# 504                           LeSeigneurDesAnneaux     01      03  11567.10
# 577                                    HarryPotter     01      03   8151.27
# 581                                    HarryPotter     01      05   7953.66
# 580                                    HarryPotter     01      01   8767.14
# 579                                    HarryPotter     01      08   7505.34
# 578                                    HarryPotter     01      04   9037.99
# 502                           LeSeigneurDesAnneaux     01      01  10263.98
# 575                                       StarWars     01      07   7946.46
# 576                                    HarryPotter     01      02   9261.89
# 583                                    HarryPotter     01      07   8406.03
# ...

# %%
videos_infosGoT_HP_BBT = videos_infos[videos_infos['name'].str.contains('HarryPotter|GameOfThrones|BigBangTheory')]

# %%
videos_infosGoT_HP_BBT.sort_values(['width']).head(350)
# Out:
#                  name season episode  duration  frame_rate  width  height
# 52      GameOfThrones     06      03   3002.14        25.0  664.0   520.0
# 51      GameOfThrones     06      02   3088.62        25.0  668.0   576.0
# 38      GameOfThrones     02      09   3134.10        25.0  686.0   560.0
# 23      GameOfThrones     04      04   3169.02        25.0  690.0   576.0
# 29      GameOfThrones     04      10   3759.26        25.0  694.0   576.0
# 761  TheBigBangTheory     02      17   1226.24        25.0  702.0   576.0
# 759  TheBigBangTheory     02      15   1205.63        25.0  702.0   576.0
# 758  TheBigBangTheory     02      14   1242.24        25.0  702.0   576.0
# 760  TheBigBangTheory     02      16   1226.43        25.0  702.0   576.0
# 46      GameOfThrones     05      07   3385.30        25.0  708.0   576.0
# 28      GameOfThrones     04      09   2910.02        25.0  712.0   576.0
# 789  TheBigBangTheory     05      23   1237.62        25.0  712.0   568.0
# ...

# %%
videos_infosGoT_HP_BBT.sort_values(['name', 'season', 'episode'])[55:]#.head(350)
# Out:
#                  name season episode  duration  frame_rate  width  height
# 57      GameOfThrones     06      06   2959.30        25.0  720.0   576.0
# 53      GameOfThrones     06      07   2895.26        25.0  720.0   576.0
# 54      GameOfThrones     06      08   3355.54        25.0  720.0   576.0
# 580       HarryPotter     01      01   8767.14        25.0  720.0   424.0
# 576       HarryPotter     01      02   9261.89        25.0  720.0   428.0
# 577       HarryPotter     01      03   8151.27        25.0  718.0   424.0
# 578       HarryPotter     01      04   9037.99        25.0  718.0   426.0
# 581       HarryPotter     01      05   7953.66        25.0  720.0   424.0
# 582       HarryPotter     01      06   8832.04        25.0  720.0   428.0
# 583       HarryPotter     01      07   8406.03        25.0  720.0   428.0
# 579       HarryPotter     01      08   7505.34        25.0  720.0   426.0
# 584  TheBigBangTheory     01      01   1319.59        25.0  720.0   576.0
# ...

# %%
current_directory = pathlib.Path('/vol/work3/maurice/dvd_extraction/dvd_extracted')
set_current_directory(current_directory)

print('Number of series', get_nb_series())
print('Number of total files', get_nb_all_files())
print('Number of episodes', get_nb_all_episodes())
print('Number of episodes per serie', get_nb_episodes_per_serie())
#print('Languages statistics', get_stats_languages())
videos_infos_got = get_movie_infos()
print('Movie informations', videos_infos_got)
# Out:
# ??? /vol/work3/maurice/dvd_extraction/dvd_extracted
# Number of series 3
# Number of total files 4489
# Number of episodes 275
# Number of episodes per serie {'TheBigBangTheory': 207, 'GameOfThrones': 60, 'HarryPotter': 8}
# ??? /vol/work3/maurice/dvd_extraction/dvd_extracted
# 0/3 /vol/work3/maurice/dvd_extraction/dvd_extracted/TheBigBangTheory
# 1/3 /vol/work3/maurice/dvd_extraction/dvd_extracted/GameOfThrones
# 2/3 /vol/work3/maurice/dvd_extraction/dvd_extracted/HarryPotter
#           duration  frame_rate  width  height
# count   273.000000       273.0  273.0   273.0
# mean   1828.942125        25.0  720.0   576.0
# std    1421.516295         0.0    0.0     0.0
# min    1066.860000        25.0  720.0   576.0
# 25%    1158.270000        25.0  720.0   576.0
# 50%    1222.250000        25.0  720.0   576.0
# 75%    1694.060000        25.0  720.0   576.0
# max    9261.890000        25.0  720.0   576.0
# ??? /vol/work3/maurice/dvd_extraction/dvd_extracted
# ...

# %% [markdown]
# # Subtitles

# %%
import spacy
import pysrt #https://github.com/byroot/pysrt
import string
nlp = spacy.load('en')

subs = pysrt.open('/vol/work3/maurice/dvd_extracted/GameOfThrones/GameOfThrones.Season01.Episode01.en.srt')

# %%
len(subs) #subs[0].start/end.seconds/minutes
# Out:
# 642

# %%
words = subs[6].text.strip().split()
x = [''.join(c for c in s if c not in string.punctuation) for s in words]
words_clean = [s.lower() for s in x if s]
print(words)
print(x)
print(words_clean)
# Out:
# ['(Man)', 'What', 'do', 'you', 'expect?', "They're", 'savages.']
# ['Man', 'What', 'do', 'you', 'expect', 'Theyre', 'savages']
# ['man', 'what', 'do', 'you', 'expect', 'theyre', 'savages']

# %%
words = []
for sub in subs:
    doc = nlp(sub.text)
    words += [w.text.lower() for w in doc if w.pos_ not in ['PUNCT', 'SPACE', 'X']]
print(len(words))
# Out:
# 3813

# %%
for w in words:
    if w not in nlp.vocab:
        print('error with word', w)
        break
# Out:
# error with word snorbs

# %%
## All english subtitles
import glob
words = []
for sub_file in sorted(glob.glob('/vol/work3/maurice/dvd_extracted/*/*.en.srt')):
    #print(sub)
    subs = pysrt.open(sub_file)
    for sub in subs:
        doc = nlp(sub.text)
        words += [w.text.lower() for w in doc if w.pos_ not in ['PUNCT', 'SPACE', 'X']]
words = list(set(words))
print(len(words))
nb_errors = 0
for w in words:
    if w not in nlp.vocab:
        #print('error with word', w)
        nb_errors += 1
print(nb_errors)

# %%
print(nb_errors)
# Out:
# 54771

# %% [markdown]
# # Detect episodes

# %% [markdown]
# ## Extract all tracks from xml files

# %%
from xml.dom import minidom
import subprocess
import os
from test_unitaire.tvd.rip import Ripper #modified version
from glob import glob
import yaml
import pandas as pd

input_path = '/vol/work2/maurice/dvd'
output_path = 'test_unitaire/xml'
path_vobsub2srt = '/people/bredin/dev/VobSub2SRT/build/bin/vobsub2srt'

for file in sorted(glob(input_path+'/*')):
    print(file)
    with open(os.devnull, mode='w') as f:
        try:
            doc = subprocess.check_output(['lsdvd', '-x', '-Ox', file], stderr = f, timeout=5)
        except subprocess.CalledProcessError as e:
            print('ERROR with this file', e.output)
    
    doc = doc.decode('utf-8', 'ignore').replace('&', '')
    doc = doc.encode('utf-8')
    ripper = Ripper()
    '''dvd_title = ripper.get_contentTitle(minidom.parseString(doc))
    if dvd_title:
        print(dvd_title)'''
    '''if not dvd_title:
        print(minidom.parseString(doc).toprettyxml())'''
    #print(file)
    #print('***')
    with open(output_path+'/'+file.split('/')[-1]+'.xml','wb') as handler:
        handler.write(doc)
# Out:
# /vol/work2/maurice/dvd/24HeuresChrono.Season01.Episodes01to04
# /vol/work2/maurice/dvd/24HeuresChrono.Season01.Episodes05to08
# /vol/work2/maurice/dvd/24HeuresChrono.Season01.Episodes09to12
# /vol/work2/maurice/dvd/24HeuresChrono.Season01.Episodes13to16
# /vol/work2/maurice/dvd/24HeuresChrono.Season01.Episodes17to20
# /vol/work2/maurice/dvd/24HeuresChrono.Season01.Episodes21to24
# /vol/work2/maurice/dvd/24HeuresChrono.Season02.Episodes01to04
# /vol/work2/maurice/dvd/24HeuresChrono.Season02.Episodes05to08
# /vol/work2/maurice/dvd/24HeuresChrono.Season02.Episodes09to12
# /vol/work2/maurice/dvd/24HeuresChrono.Season02.Episodes13to16
# /vol/work2/maurice/dvd/24HeuresChrono.Season02.Episodes17to20
# /vol/work2/maurice/dvd/24HeuresChrono.Season02.Episodes21to24
# /vol/work2/maurice/dvd/24HeuresChrono.Season03.Episodes01to04
# /vol/work2/maurice/dvd/24HeuresChrono.Season03.Episodes05to08
# /vol/work2/maurice/dvd/24HeuresChrono.Season03.Episodes09to12
# ...

# %%
from xml.dom import minidom
import subprocess
import os
from joblib import Parallel, delayed
import multiprocessing
from test_unitaire.tvd.rip import Ripper #modified version
from glob import glob
import yaml
import pandas as pd
import csv

xml_path = 'test_unitaire/xml/'
input_path = '/vol/work2/maurice/dvd'
output_rip = '/vol/work1/maurice/rip_temp/'

files = glob(xml_path+'*.xml')

texts = []
for f in files:
    #print('FILE', f)
    fi = open(f, 'r', encoding = 'utf-8', errors = 'ignore' )
    content = fi.read()
    content = content.replace('&', '')
    texts.append(content)

to_rip = []
for t in texts:
    current = minidom.parseString(t)
    ripper = Ripper()
    tracks = ripper.get_tracks(current)

    title = current.getElementsByTagName('device')[0].firstChild.data
    title = title.split('/')[-1]
    nsfl = title.split('.')
    name = nsfl[0]
    season = int(nsfl[1].strip('Season'))
    fl = nsfl[2].strip('Episodes').split('to')
    first = int(fl[0])
    last = int(fl[1])
    for track in tracks:
        to_rip.append((name, season, first, last, track.title))

    #audio = ripper.get_languages(current, ref_episodesef['from'], ref_episodes['to'])
            
with open('to_rip.txt', mode='w') as file:
    wr = csv.writer(file)#, delimiter='\n')
    for x in to_rip:
        wr.writerow(x)

# %%
from xml.dom import minidom
import subprocess
import os
from joblib import Parallel, delayed
import multiprocessing
from test_unitaire.tvd.rip import Ripper #modified version
from glob import glob
import yaml
import pandas as pd
import csv

xml_path = 'test_unitaire/'
input_path = '/vol/work2/maurice/dvd'
output_rip = '/vol/work1/maurice/rip_temp/'

files = glob(xml_path+'xml/*.xml')

with open(xml_path+'data.yml', 'r', encoding = 'utf-8', errors = 'ignore') as file:
    data_str = file.read()
data = yaml.load(data_str)

texts = {}

for f in files:
    title = f.split('/')[-1]
    title = title.split('.xml')[0]
    #print('FILE', f, title)
    fi = open(f, 'r', encoding = 'utf-8', errors = 'ignore' )
    content = fi.read()
    content = content.replace('&', '')
    texts[title] = content

#print()

to_analyse = []

def to_time(time):
    h,m = divmod(time, 3600)
    m,s = divmod(m, 60)
    return ''+str(int(h))+':'+str(int(m))+':'+str(int(s))

to_rip = []

if not os.path.exists('output_rip'):#+name):
    os.makedirs('output_rip')#+name)

for title, t in texts.items():
    current = minidom.parseString(t)
    ripper = Ripper()
    tracks = ripper.get_tracks(current)

    #print(ripper.get_contentTitle(current))
    title_auto = current.getElementsByTagName('device')[0].firstChild.data
    title_auto = title_auto.split('/')[-1]
    nsfl = title_auto.split('.')
    name = nsfl[0]
    season = int(nsfl[1].strip('Season'))
    fl = nsfl[2].strip('Episodes').split('to')
    first = int(fl[0])
    last = int(fl[1])
    title_auto = title_auto.replace('Season', 'S')
    title_auto = title_auto.replace('Episodes', 'E')
    #print(name, season, first, last)
    #print(title)
    if title in data:
        ref_episodes = data[title]
    for track in tracks:
        #if track.duration == 0:
        ix_ref = '-'
        if int(track.title) in ref_episodes['episodes']:
            ix_ref = track.title
        to_analyse.append({'title':title_auto.strip(), 'duration':to_time(track.duration),
                           'vts':track.vts, 'ttn':track.ttn, 'ix':track.title, 'ix_ref':ix_ref})
        if track.duration > 60*5:
            # RIP
            to_rip.append((name, season, first, last, track.title))

    #audio = ripper.get_languages(current, ref_episodesef['from'], ref_episodes['to'])

    '''with open(os.devnull, mode='w') as f:
        for track in tracks:
            subprocess.call([
            'HandBrakeCLI', '-i', f'{input_path}/{name}.Season{int(season):02d}.Episodes{first:02d}to{last:02d}', '-t', track.title, '-o',
            f'{output_rip}/{name}.Season{int(season):02d}.Track_ix{track.title}.mkv',
            '--cfr', '--crop', '0:0:0:0', '-r', '25', '--all-audio', '--all-subtitles'
            ])'''
            
with open('to_rip.txt', mode='w') as file:
    wr = csv.writer(file)#, delimiter='\n')
    for x in to_rip:
        wr.writerow(x)
    
'''def rip(infos):
    name, season, first, last, track.title = infos
    with open(os.devnull, mode='w') as f:
        subprocess.call([
        'HandBrakeCLI', '-i', f'{input_path}/{name}.Season{int(season):02d}.Episodes{first:02d}to{last:02d}', '-t', track.title, '-o',
        f'{output_rip}/{name}.Season{int(season):02d}.Track_ix{track.title}.mkv',
        '--cfr', '--crop', '0:0:0:0', '-r', '25', '--all-audio', '--all-subtitles'
        ])

print('begin rip')
num_cores = multiprocessing.cpu_count()
results = Parallel(n_jobs=num_cores)(delayed(rip)(infos) for infos in to_rip)'''


from IPython.display import display, HTML
affichage = pd.DataFrame(to_analyse, columns=['title','duration','vts','ttn', 'ix', 'ix_ref'])
affichage.to_csv('data_corpus.csv', sep='\t', encoding='utf-8', index=False)
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    #print(affichage.to_string(index=False))
    display(HTML(affichage.to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>title</th>
#       <th>duration</th>
#       <th>vts</th>
#       <th>ttn</th>
#       <th>ix</th>
#       <th>ix_ref</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Lost.S01.E01to04</td>
#       <td>2434.44</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1</td>
#       <td>-</td>
#     </tr>
#     <tr>
#       <td>Lost.S01.E01to04</td>
#       <td>0.48</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>2</td>
#       <td>-</td>
#     </tr>
#     <tr>
#       <td>Lost.S01.E01to04</td>
#       <td>2435.88</td>
#       <td>1.0</td>
#       <td>3.0</td>
#       <td>3</td>
#       <td>-</td>
#     </tr>
#     <tr>
#       <td>Lost.S01.E01to04</td>
#       <td>2318.96</td>
#       <td>2.0</td>
#       <td>1.0</td>
#       <td>4</td>
#       <td>-</td>
#     </tr>
#     <tr>
#       <td>Lost.S01.E01to04</td>
#       <td>2319.44</td>
#       <td>2.0</td>
# ...

# %%
from xml.dom import minidom
from test_unitaire.tvd.rip import Ripper #modified version
from glob import glob
import yaml
import pandas as pd

xml_path = 'test_unitaire/'

files = glob(xml_path+'*.xml')

with open(xml_path+'data.yml', 'r', encoding = 'utf-8', errors = 'ignore') as file:
    data_str = file.read()
data = yaml.load(data_str)

texts = []

for f in files:
    print('FILE', f)
    fi = open(f, 'r', encoding = 'utf-8', errors = 'ignore' )
    content = fi.read()
    content = content.replace('&', '')
    texts.append(content)

print()

to_analyse = []

def to_time(time):
    h,m = divmod(time, 3600)
    m,s = divmod(m, 60)
    return ''+str(int(h))+':'+str(int(m))+':'+str(int(s))

for t in texts:
    current = minidom.parseString(t)
    ripper = Ripper()
    #print('Content title : ' + ripper.get_contentTitle(current))
    tracks = ripper.get_tracks(current)#ripper.sort_tracks(ripper.get_tracks(current))

    #print('(non-sorted) tracks lists')
    #for t in tracks:
    #    print(t.title, t.duration, t.vts, t.ttn)
    
    print(ripper.get_contentTitle(current))
    if ripper.get_contentTitle(current) in data:
        ref_episodes = data[ripper.get_contentTitle(current)]
        episodes = ripper.sort_episodes(ripper.get_episodes(tracks, ref_episodes['from'], ref_episodes['to']))
        #print(ref_episodes['episodes'])
        '''for ix in ref_episodes['episodes']:
            to_analyse.append({'title':ripper.get_contentTitle(current), 'duration':to_time(tracks[ix-1].duration),
                           'vts':tracks[ix-1].vts, 'ttn':tracks[ix-1].ttn, 'ix':ix})'''
        
        for track in tracks:
            ix_ref = '-'
            if int(track.title) in ref_episodes['episodes']:
                ix_ref = track.title
            to_analyse.append({'title':ripper.get_contentTitle(current), 'duration':to_time(track.duration),
                           'vts':track.vts, 'ttn':track.ttn, 'ix':ix_ref})

    #audio = ripper.get_languages(current, ref_episodesef['from'], ref_episodes['to'])

affichage = pd.DataFrame(to_analyse, columns=['title','duration','vts','ttn','ix'])
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(affichage)
# Out:
# FILE test_unitaire/GOT.S01.D01.xml
# FILE test_unitaire/SFU.S01.D01.xml
# FILE test_unitaire/TheOffice.S01.D01.xml
# FILE test_unitaire/WD.S01.D01.xml
# FILE test_unitaire/BBT.S01.D01.xml
# FILE test_unitaire/LOTR.E01.xml
# FILE test_unitaire/BreakingBad.S01.D01.xml
# FILE test_unitaire/Friends.S01.D01B.xml
# FILE test_unitaire/Homeland.S01.D01.xml
# FILE test_unitaire/24HeuresChrono.S01.D01.xml
# FILE test_unitaire/Urgences.S01.D01.xml
# FILE test_unitaire/Buffy.S01.D01.xml
# FILE test_unitaire/TheOffice.S09.D05.xml
#
# GAME_OF_THRONES_S1_DISC1
# SIX_FEET_UNDER_DISC1
# THE_OFFICE_S1_DVD1
# THE_WALKING_DEAD_S1_D1
# BIG_BANG_THEORY_SEASON_1_DISC1
# LOTR_THE_FELLOWSHIP_OF_THE_RING
# BREAKING_BAD_SEASON_1_DISC_1
# FRIENDS_SERIES1_D1A
# HOMELAND_S1_DISC1
# 24_DISC1
# ER_S1_T5A_D1
# BUFFY_DISC1
# THE_OFFICE_S9D5
# Empty DataFrame
# Columns: [title, duration, vts, ttn, ix]
# Index: []

# %%
from xml.dom import minidom
from test_unitaire.tvd.rip import Ripper #modified version
from glob import glob
import yaml
import numpy as np
import pandas as pd

to_print = False

xml_path = 'test_unitaire/'

files = glob(xml_path+'xml/*.xml')

with open(xml_path+'data.yml', 'r', encoding = 'utf-8', errors = 'ignore') as file:
    data_str = file.read()
data = yaml.load(data_str)

texts = {}

for f in files:
    title = f.split('/')[-1]
    title = title.split('.xml')[0]
    #print('FILE', f, title)
    fi = open(f, 'r', encoding = 'utf-8', errors = 'ignore' )
    content = fi.read()
    content = content.replace('&', '')
    texts[title] = content

print()

to_analyse = []

def to_time(time):
    h,m = divmod(time, 3600)
    m,s = divmod(m, 60)
    return ''+str(int(h))+':'+str(int(m))+':'+str(int(s))

from test_unitaire.tvd.rip import Track
def heuristique_xml(content, first, last):
    track = content.getElementsByTagName('track')
    tracks = []

    for t in track:
        ix = t.getElementsByTagName('ix')[0]
        length = t.getElementsByTagName('length')[0]
        vts = t.getElementsByTagName('vts')[0]
        ttn = t.getElementsByTagName('ttn')[0]

        t = Track(ix.firstChild.data, length.firstChild.data, vts.firstChild.data, ttn.firstChild.data)
        tracks.append(t)
        
    nbEpisodes = (last - first) + 1
    
    if len(tracks) == nbEpisodes:
        return tracks
    
    if len(tracks) < nbEpisodes:
        print('ERROR : len(tracks) couldn\'t be less than nbEpisodes')
    
    #tracks = sorted(tracks, key = lambda x: (x.duration, x.vts, x.ttn))
    #tracks = sorted(sorted(sorted(tracks, key = lambda x : x.ttn), key = lambda x : x.vts), key = lambda x : x.duration, reverse=True)
    #print(tracks)
    
    #if nbEpisodes == 1:
    #    return tracks
    
    tracks = sorted(tracks, key = lambda x: (x.duration), reverse=True)
    if to_print:
        for track in tracks:
            print('title ' + track.title + ' duration ' + str(track.duration) + ' vts ' + str(track.vts) + ' ttn ' + str(track.ttn))
        print('***')
    
    '''deltas = []
    for i,t in enumerate(tracks):
        if i+1 >= nbEpisodes:
            break
        deltas.append(t.duration - tracks[i].duration)
    
    if deltas[0] > 1.2 * deltas[1]:
        tracks = tracks[1:nbEpisodes+1]'''
        
    if nbEpisodes == 1:
        return [tracks[0]]
    
    if tracks[0].duration > tracks[1].duration*1.5 :
        tracks = tracks[1:]#nbEpisodes+1]
    #else:
    #    tracks = tracks[0:nbEpisodes]
    
    deltas = []
    for i,t in enumerate(tracks):
        if i + 1 == len(tracks):
            break
        deltas.append(t.duration - tracks[i + 1].duration)
    deltas = np.asarray(deltas)
    #print(deltas, np.mean(deltas), np.where(deltas > np.mean(deltas))[0][0])
    max_size = np.where(deltas > np.mean(deltas))[0][0] + 1
    tracks = tracks[0:max_size]

    if to_print:
        for track in tracks:
            print('title ' + track.title + ' duration ' + str(track.duration) + ' vts ' + str(track.vts) + ' ttn ' + str(track.ttn))
        print('***')

    #if tracks[0].duration > 1.5 * tracks[1].duration:
    #    tracks = tracks[1:max_size]#nbEpisodes+1]
    
    tracks = sorted(sorted(tracks, key = lambda x : x.ttn), key = lambda x : x.vts)
    
    tracks = tracks[0:nbEpisodes]
    
    if to_print:
        for track in tracks:
            print('title ' + track.title + ' duration ' + str(track.duration) + ' vts ' + str(track.vts) + ' ttn ' + str(track.ttn))
    
    return tracks[0:nbEpisodes]

for title, t in texts.items():
    current = minidom.parseString(t)
    ripper = Ripper()
    #print('Content title : ' + ripper.get_contentTitle(current))
    tracks = ripper.get_tracks(current)#ripper.sort_tracks(ripper.get_tracks(current))

    #print('(non-sorted) tracks lists')
    #for t in tracks:
    #    print(t.title, t.duration, t.vts, t.ttn)
    
    #print(title, ripper.get_contentTitle(current))
    if title in data:
        ref_episodes = data[title]
        
        from_to = title.split('Episodes')[1].split('to')
        from_ = int(from_to[0])
        to_ = int(from_to[1])
        
        episodes_ = heuristique_xml(current, from_, to_)
        episodes = []
        for epi in episodes_:
            episodes.append(int(epi.title))
        #print(ref_episodes['episodes'], episodes)
        diff = list(set(ref_episodes['episodes']) - set(episodes))
        if len(diff) > 0:
            print(title, 'diff', diff, 'ref', ref_episodes['episodes'], 'hyp', episodes)
            for ix in ref_episodes['episodes']:
                to_analyse.append({'title':title, 'duration':to_time(tracks[ix-1].duration),
                           'vts':tracks[ix-1].vts, 'ttn':tracks[ix-1].ttn, 'ix':ix}) #ripper.get_contentTitle(current)

    #audio = ripper.get_languages(current, ref_episodesef['from'], ref_episodes['to'])

affichage = pd.DataFrame(to_analyse, columns=['title','duration','vts','ttn','ix'])
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(affichage)
# Out:
# 24HeuresChrono.Season09.Episodes01to03 diff [5] ref [3, 4, 5] hyp [3, 4]
# 24HeuresChrono.Season09.Episodes10to12 diff [3, 4] ref [3, 4, 5] hyp [5]
# BattlestarGalactica.Season02.Episodes09to10 diff [1] ref [1, 2] hyp [2]
# BattlestarGalactica.Season02.Episodes19to20 diff [2] ref [1, 2] hyp [1]
# BattlestarGalactica.Season04.Episodes11to12 diff [1] ref [1, 2] hyp [2]
# BattlestarGalactica.Season04.Episodes16to18 diff [1, 2] ref [1, 2, 3] hyp [3]
# BattlestarGalacticaCaprica.Season01.Episodes02to04 diff [11] ref [7, 10, 11] hyp [7, 9, 10]
# BattlestarGalacticaCaprica.Season01.Episodes05to08 diff [17, 14] ref [8, 11, 14, 17] hyp [8, 10, 11, 12]
# BattlestarGalacticaCaprica.Season01.Episodes09to11 diff [9] ref [3, 6, 9] hyp [3, 5, 6]
# BattlestarGalacticaCaprica.Season01.Episodes12to15 diff [26, 23] ref [6, 9, 23, 26] hyp [6, 8, 9, 10]
# BreakingBad.Season01.Episodes01to03 diff [2, 3] ref [1, 2, 3] hyp [1]
# BreakingBad.Season04.Episodes11to13 diff [1, 2] ref [1, 2, 3] hyp [3]
# ...

# %%
# Out:
# (0, 3003)

# %%
# ?divmod
# Out:
# Signature: divmod(x, y, /)
# Docstring: Return the tuple (x//y, x%y).  Invariant: div*y + mod == x.
# Type:      builtin_function_or_method

# %%
from xml.dom import minidom
from test_unitaire.tvd.rip import Ripper #modified version
from glob import glob
import yaml

xml_path = 'test_unitaire/'

files = glob(xml_path+'*.xml')

data = open(xml_path+'data.yml', 'r', encoding = 'utf-8', errors = 'ignore')
data = data.read()
data = yaml.load(data)

texts = []

for f in files:
    print('FILE', f)
    fi = open(f, 'r', encoding = 'utf-8', errors = 'ignore' )
    content = fi.read()
    content = content.replace('&', '')
    texts.append(content)

print()
    
verification = True
for t in texts:
    if verification:
        current = minidom.parseString(t)
        ripper = Ripper()
        print('Content title : ' + ripper.get_contentTitle(current))
        tracks = ripper.sort_tracks(ripper.get_tracks(current))

        input = data.get(ripper.get_contentTitle(current))

        episodes = ripper.get_episodes(tracks, input.get('from'), input.get('to'))
        episodes = ripper.sort_episodes(episodes)

        print('sorted tracks lists')
        for t in tracks:
            print(t.title, t.duration)
        print('sorted episodes lists')
        for e in episodes:
            print(e.title, e.duration)

        audio = ripper.get_languages(current, input.get('from'), input.get('to'))

        test_episodes = input.get('episodes')
        test_audio = input.get('audio')

        i = 0
        print('video')
        while i < len(test_episodes) and verification:
            print(str(test_episodes[i]) + '    ' + str(episodes[i].title))
            if int(test_episodes[i]) != int(episodes[i].title):
                verification = False
                print('ERROR of video : ' + ripper.get_contentTitle(current))
            i += 1
        j = 0

        print('audio')
        while j<len(test_audio) and verification:
            print(str(test_audio[j]) + '    ' + str(audio[j].title))
            if int(test_audio[j]) != int(audio[j].title):
                verification = False
                print('ERROR of audio : ' + ripper.get_contentTitle(current))
            j += 1
# Out:
# FILE test_unitaire/GOT.S01.D01.xml
# FILE test_unitaire/SFU.S01.D01.xml
# FILE test_unitaire/TheOffice.S01.D01.xml
# FILE test_unitaire/WD.S01.D01.xml
# FILE test_unitaire/BBT.S01.D01.xml
# FILE test_unitaire/LOTR.E01.xml
# FILE test_unitaire/BreakingBad.S01.D01.xml
# FILE test_unitaire/Friends.S01.D01B.xml
# FILE test_unitaire/Homeland.S01.D01.xml
# FILE test_unitaire/24HeuresChrono.S01.D01.xml
# FILE test_unitaire/Urgences.S01.D01.xml
# FILE test_unitaire/Buffy.S01.D01.xml
# FILE test_unitaire/TheOffice.S09.D05.xml
#
# Content title : GAME_OF_THRONES_S1_DISC1
# sorted tracks lists
# 3 6727.76
# 1 3546.24
# 2 3182.0
# 14 1844.8
# 31 211.72
# 19 175.6
# 23 161.0
# 29 158.12
# 20 151.88
# 26 150.16
# 18 142.48
# 28 133.6
# 25 124.92
# 21 111.64
# 24 108.76
# 15 102.64
# 27 102.56
# 16 91.6
# 17 77.64
# 22 58.92
# 32 7.48
# 4 1.52
# 5 1.52
# 6 1.52
# 7 1.52
# 8 1.52
# 9 1.52
# 33 1.52
# 34 1.52
# 35 1.52
# 10 0.48
# 11 0.48
# 12 0.48
# 13 0.48
# 30 0.48
# sorted episodes lists
# ...
